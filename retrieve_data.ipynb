# %% [markdown]
# ### Import Required Libraries and Set Up Environment Variables

# %%
# Dependencies
import requests
import time
from dotenv import load_dotenv
import os
import pandas as pd
import json
import os
from datetime import datetime
## Load the NASA_API_KEY from the env file
load_dotenv()
NASA_API_KEY = os.getenv('NASA_API_KEY')

# %% [markdown]
# ### CME Data

# %%
# Set the base URL to NASA's DONKI API:
base_url = "https://api.nasa.gov/DONKI/LTVg5VoACPM7ySf79Ht7BVELqikDF2F567fAzu6z"

# Set the specifier for CMEs:
CME = "CME"

# Search for CMEs published between a begin and end date
startDate = "2013-05-01"
endDate   = "2024-05-01"

# Build URL for CME
CME_url = ('https://api.nasa.gov/DONKI/CME?startDate=yyyy-MM-dd&endDate=yyyy-MM-dd&api_key=DEMO_KEY')
#CME_url = base_url + '?Format' + 'CME'
#CME_url
#print(json.dumps(CME_url, indent=4))

# %%
# Make a "GET" request for the CME URL and store it in a variable named cme_response
cme_response = requests.get(CME_url)
cme_response
# Out:
# <Response [200]>

# %%
# Convert the response variable to json and store it as a variable named cme_json
cme_json = cme_response.json()
cme_json
# Out:
# [{'activityID': '2024-09-21T11:12:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2024-09-21T11:12Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'},
#    {'displayName': 'STEREO A: SECCHI/COR2'}],
#   'sourceLocation': '',
#   'activeRegionNum': None,
#   'note': 'Thin diffuse CME seen to the NW in all coronagraphs. The source is best observed in SDO AIA 171 as field line movement on or just beyond the NW limb starting around 2024-09-21T10:39Z.',
#   'submissionTime': '2024-09-21T20:17Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/33526/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2024-09-21T17:07Z',
#     'latitude': 29.0,
#     'longitude': 99.0,
#     'halfAngle': 10.0,
#     'speed': 651.0,
#     'type': 'C',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'Triangulated measurement between SOHO LASCO C2/C3 and STEREO COR2A, with the source observed in SDO on/near the NW limb.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': 12.7,
#     'submissionTime': '2024-09-21T20:18Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/33527/-1',
#     'enlilList': None}],
#   'linkedEvents': None},
#  {'activityID': '2024-09-21T16:12:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2024-09-21T16:12Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'},
#    {'displayName': 'STEREO A: SECCHI/COR2'}],
#   'sourceLocation': '',
#   'activeRegionNum': None,
#   'note': 'CME visible to the NE in SOHO LASCO C2/C3 and STEREO A COR2. The source is believed to be backsided, with field line movement visible beyond the east limb in GOES SUVI 284 and SDO AIA 171 starting around 2024-09-21T15:00Z.',
#   'submissionTime': '2024-09-23T15:16Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/33535/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2024-09-22T08:18Z',
#     'latitude': 71.0,
#     'longitude': -107.0,
#     'halfAngle': 38.0,
#     'speed': 268.0,
#     'type': 'S',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'Best fit measurement using several frames of SOHO LASCO C2/C3 and STEREO A COR2 and a farsided source location as observed in EUV imagery.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': 12.0,
#     'submissionTime': '2024-09-23T15:17Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/33536/-1',
#     'enlilList': None}],
#   'linkedEvents': None},
#  {'activityID': '2024-09-21T20:00:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2024-09-21T20:00Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'}],
#   'sourceLocation': 'N25W80',
#   'activeRegionNum': None,
#   'note': 'Narrow CME seen to the NW in SOHO LASCO C2/C3. Not visible in STEREO A COR2 due to a data gap from 2024-09-21T16:53Z-23:09Z.The source is a narrow eruption from N25W80 at 2024-09-21T19:24Z. Ejecta and brightening seen in SDO AIA 304/131. Opening field lines and ejecta seen in SDO AIA 171. Faint dimming seen extending a bit further onto the disk at 19:44Z in SDO AIA 193.',
#   'submissionTime': '2024-09-23T15:53Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/33542/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2024-09-22T02:17Z',
#     'latitude': 55.0,
#     'longitude': 80.0,
#     'halfAngle': 10.0,
#     'speed': 561.0,
#     'type': 'C',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'Measurement based on source location using SOHO LASCO C2 imagery.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': 7.0,
#     'submissionTime': '2024-09-23T15:54Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/33543/-1',
#     'enlilList': None}],
#   'linkedEvents': None},
#  {'activityID': '2024-09-22T07:12:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2024-09-22T07:12Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'},
#    {'displayName': 'STEREO A: SECCHI/COR2'}],
#   'sourceLocation': '',
#   'activeRegionNum': None,
#   'note': 'CME visible to the NW in SOHO LASCO C2/C3 and STEREO A COR2. The source is best seen in STEREO A EUV 195 as opening field lines starting around 2024-09-22T05:25Z.',
#   'submissionTime': '2024-09-23T17:56Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/33548/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2024-09-22T20:37Z',
#     'latitude': 19.0,
#     'longitude': 136.0,
#     'halfAngle': 17.0,
#     'speed': 255.0,
#     'type': 'S',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'Measurement based on best fit between SOHO LASCO C2/C3 and STEREO A COR2 in SWPC_CAT as well as source location beyond west limb.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': 9.7,
#     'submissionTime': '2024-09-23T17:57Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/33549/-1',
#     'enlilList': [{'modelCompletionTime': '2024-09-23T18:37Z',
#       'au': 2.0,
#       'estimatedShockArrivalTime': None,
#       'estimatedDuration': None,
#       'rmin_re': None,
#       'kp_18': None,
#       'kp_90': None,
#       'kp_135': None,
#       'kp_180': None,
#       'isEarthGB': False,
#       'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/33553/-1',
#       'impactList': None,
#       'cmeIDs': ['2024-09-22T07:12:00-CME-001']}]}],
#   'linkedEvents': None},
#  {'activityID': '2024-09-22T14:48:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2024-09-22T14:48Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'},
#    {'displayName': 'STEREO A: SECCHI/COR2'}],
#   'sourceLocation': '',
#   'activeRegionNum': None,
#   'note': 'Narrow CME visible to the NW in SOHO LASCO C2/C3 and STEREO A COR2. The source is unclear, and may be beyond the west limb.',
#   'submissionTime': '2024-09-23T15:34Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/33540/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2024-09-22T22:51Z',
#     'latitude': 34.0,
#     'longitude': None,
#     'halfAngle': 13.0,
#     'speed': 470.0,
#     'type': 'S',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'Plane-of-sky',
#     'note': 'This CME was not clearly measurable using STEREO A COR2 due to poor quality difference imagery, so a plane of sky measurement using SOHO difference imagery in SWPC_CAT was taken.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': 7.2,
#     'submissionTime': '2024-09-23T15:35Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/33541/-1',
#     'enlilList': None}],
#   'linkedEvents': None},
#  {'activityID': '2024-09-22T19:12:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2024-09-22T19:12Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'}],
#   'sourceLocation': '',
#   'activeRegionNum': None,
#   'note': 'Narrow CME first seen in the NW by SOHO LASCO C2 beginning at 2024-09-22T19:12Z, as well as by SOHO LASCO C3 in later frames. There is no STEREO A COR2 imagery available for this event due to a data gap beginning at 2024-09-22T17:38Z. The source of this eruption is likely far sided, evidenced by field line movement seen beyond the NW limb in SDO AIA 171 around 2024-09-22T19:00Z.',
#   'submissionTime': '2024-09-23T15:26Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/33537/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2024-09-23T01:50Z',
#     'latitude': 35.0,
#     'longitude': 95.0,
#     'halfAngle': 15.0,
#     'speed': 537.0,
#     'type': 'C',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'Measurement using source location just beyond the limb and SOHO imagery only due to STEREO A COR2 data gap.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': 9.9,
#     'submissionTime': '2024-09-23T15:27Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/33538/-1',
#     'enlilList': [{'modelCompletionTime': '2024-09-22T23:25Z',
#       'au': 2.0,
#       'estimatedShockArrivalTime': None,
#       'estimatedDuration': None,
#       'rmin_re': None,
#       'kp_18': None,
#       'kp_90': None,
#       'kp_135': None,
#       'kp_180': None,
#       'isEarthGB': False,
#       'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/33539/-1',
#       'impactList': None,
#       'cmeIDs': ['2024-09-22T19:12:00-CME-001']}]}],
#   'linkedEvents': None},
#  {'activityID': '2024-09-22T21:36:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2024-09-22T21:36Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'},
#    {'displayName': 'STEREO A: SECCHI/COR2'}],
#   'sourceLocation': 'S23E65',
#   'activeRegionNum': 13835,
#   'note': 'CME first seen in the SW by SOHO LASCO C2 beginning at 2024-09-22T21:36Z. The source of this event is an M3.7 flare and filament eruption from S23E65 beginning at 2024-09-22T21:12Z. This flare is seen clearly in SDO AIA 94 and 131, and the filament material is seen best in SDO AIA 304. Field line opening is also visible in SDO AIA 171, 193, and GOES SUVI 284 along with post eruptive arcades visible in SDO AIA 94 and 131. This filament appears to deflect towards the SW as it progresses as seen in GOES SUVI 304. A faint EUV wave seen in SDO AIA 193 also appears to expand more to the west.',
#   'submissionTime': '2024-09-23T14:31Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/33529/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2024-09-23T00:27Z',
#     'latitude': -41.0,
#     'longitude': -25.0,
#     'halfAngle': 37.0,
#     'speed': 1239.0,
#     'type': 'O',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'Measurement of the bulk of the CME based on best fit between SOHO LASCO C2/C3 and STEREO A COR2 in SWPC_CAT.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': 15.2,
#     'submissionTime': '2024-09-23T14:44Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/33530/-1',
#     'enlilList': [{'modelCompletionTime': '2024-09-23T01:28Z',
#       'au': 2.0,
#       'estimatedShockArrivalTime': '2024-09-25T18:00Z',
#       'estimatedDuration': None,
#       'rmin_re': None,
#       'kp_18': None,
#       'kp_90': 3,
#       'kp_135': 4,
#       'kp_180': 5,
#       'isEarthGB': True,
#       'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/33531/-1',
#       'impactList': [{'isGlancingBlow': False,
#         'location': 'Lucy',
#         'arrivalTime': '2024-09-25T10:00Z'},
#        {'isGlancingBlow': True,
#         'location': 'STEREO A',
#         'arrivalTime': '2024-09-26T02:00Z'}],
#       'cmeIDs': ['2024-09-22T21:36:00-CME-001']}]},
#    {'isMostAccurate': True,
#     'time21_5': '2024-09-23T00:04Z',
#     'latitude': -18.0,
#     'longitude': -24.0,
#     'halfAngle': 45.0,
#     'speed': 1381.0,
#     'type': 'O',
#     'featureCode': 'SH',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'Measurement of the wider, fainter, SHOCK of the CME.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': 17.4,
#     'submissionTime': '2024-09-23T14:43Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/33532/-1',
#     'enlilList': [{'modelCompletionTime': '2024-09-23T11:50Z',
#       'au': 2.0,
#       'estimatedShockArrivalTime': '2024-09-24T18:55Z',
#       'estimatedDuration': 28.5,
#       'rmin_re': 5.4,
#       'kp_18': None,
#       'kp_90': 6,
#       'kp_135': 8,
#       'kp_180': 8,
#       'isEarthGB': False,
#       'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/33533/-1',
#       'impactList': [{'isGlancingBlow': False,
#         'location': 'Lucy',
#         'arrivalTime': '2024-09-24T14:29Z'},
#        {'isGlancingBlow': True,
#         'location': 'STEREO A',
#         'arrivalTime': '2024-09-25T02:00Z'}],
#       'cmeIDs': ['2024-09-22T21:36:00-CME-001']}]}],
#   'linkedEvents': [{'activityID': '2024-09-22T21:12:00-FLR-001'}]},
#  {'activityID': '2024-09-23T02:00:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2024-09-23T02:00Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'}],
#   'sourceLocation': '',
#   'activeRegionNum': None,
#   'note': 'CME visible to the NW in SOHO LASCO C2/C3. Not clearly visible in STEREO A COR2 imagery, and possibly obscured by the bright streamer. The potential source is opening field lines best seen in GOES SUVI 284 at 2024-09-23T02:00Z, on the far side.',
#   'submissionTime': '2024-09-23T18:44Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/33551/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2024-09-23T08:47Z',
#     'latitude': 36.0,
#     'longitude': None,
#     'halfAngle': 15.0,
#     'speed': 512.0,
#     'type': 'C',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'Plane-of-sky',
#     'note': 'Plane of sky measurement using SOHO LASCO C2 imagery in SWPC_CAT.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': 5.6,
#     'submissionTime': '2024-09-23T18:44Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/33552/-1',
#     'enlilList': None}],
#   'linkedEvents': None},
#  {'activityID': '2024-09-23T09:12:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2024-09-23T09:12Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'},
#    {'displayName': 'STEREO A: SECCHI/COR2'}],
#   'sourceLocation': 'N50W20',
#   'activeRegionNum': None,
#   'note': 'Faint CME seen to the NE in SOHO LASCO C2/C3 and STEREO A COR2. The potential source is a filament eruption seen lifting off starting around 2024-09-23T07:17Z in SDO AIA 304 centered around N50W20. Dimming is also visible in SDO AIA 193. The eruption is also visible from the point of view of STEREO A EUV 195. While the filament does not clearly deflect in EUV imagery, this is the most likely candidate source for this CME based on event timing and location.',
#   'submissionTime': '2024-09-23T18:56Z',
#   'versionId': 3,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/33546/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2024-09-23T16:40Z',
#     'latitude': 41.0,
#     'longitude': -20.0,
#     'halfAngle': 14.0,
#     'speed': 454.0,
#     'type': 'S',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'Measurement based on best fit between SOHO LASCO C2/C3 and STEREO A COR2 imagery in SWPC_CAT.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': 10.0,
#     'submissionTime': '2024-09-23T17:42Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/33547/-1',
#     'enlilList': [{'modelCompletionTime': '2024-09-23T18:21Z',
#       'au': 2.0,
#       'estimatedShockArrivalTime': None,
#       'estimatedDuration': None,
#       'rmin_re': None,
#       'kp_18': None,
#       'kp_90': None,
#       'kp_135': None,
#       'kp_180': None,
#       'isEarthGB': False,
#       'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/33562/-1',
#       'impactList': None,
#       'cmeIDs': ['2024-09-23T09:12:00-CME-001']}]}],
#   'linkedEvents': None},
#  {'activityID': '2024-09-23T20:48:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2024-09-23T20:48Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'},
#    {'displayName': 'STEREO A: SECCHI/COR2'}],
#   'sourceLocation': 'S33W23',
#   'activeRegionNum': None,
#   'note': 'Slow, loop-shaped CME seen propagating to the southwest in SOHO C2/C3 starting around 2024-09-23T20:48Z and also seen in STEREO A which accelerates with time. May be associated with two areas of dimming seen best in GOES 284 which may represent footpoints for this eruption near S40W05 and S25W40 (centerpoint S33W23) located near the vicinity of AR3827.',
#   'submissionTime': '2024-09-24T12:18Z',
#   'versionId': 2,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/33557/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2024-09-24T10:13Z',
#     'latitude': -38.0,
#     'longitude': 23.0,
#     'halfAngle': 30.0,
#     'speed': 338.0,
#     'type': 'S',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'Two spacecraft measurement of the leading edge of the CME, capturing the half-width more closely in STEREO A than SOHO, where it appears wider.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': 18.0,
#     'submissionTime': '2024-09-24T12:04Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/33558/-1',
#     'enlilList': [{'modelCompletionTime': '2024-09-24T12:01Z',
#       'au': 2.0,
#       'estimatedShockArrivalTime': '2024-09-28T00:00Z',
#       'estimatedDuration': None,
#       'rmin_re': None,
#       'kp_18': None,
#       'kp_90': 3,
#       'kp_135': 4,
#       'kp_180': 5,
#       'isEarthGB': True,
#       'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/33559/-1',
#       'impactList': [{'isGlancingBlow': True,
#         'location': 'Mars',
#         'arrivalTime': '2024-09-30T22:00Z'},
#        {'isGlancingBlow': True,
#         'location': 'STEREO A',
#         'arrivalTime': '2024-09-28T04:00Z'}],
#       'cmeIDs': ['2024-09-23T20:48:00-CME-001']}]}],
#   'linkedEvents': [{'activityID': '2024-09-28T07:00:00-IPS-001'}]},
#  {'activityID': '2024-09-24T04:12:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2024-09-24T04:12Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'},
#    {'displayName': 'STEREO A: SECCHI/COR2'}],
#   'sourceLocation': 'S60W02',
#   'activeRegionNum': None,
#   'note': 'CME seen to the south-southeast in SOHO/STEREO A imagery, overlapping with CME: 2024-09-23T20:48Z; possibly associated with a filament eruption at far southern latitudes seen best in SDO 171 around 2024-09-24T01:48Z.',
#   'submissionTime': '2024-09-24T12:57Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/33560/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2024-09-24T10:06Z',
#     'latitude': -53.0,
#     'longitude': -22.0,
#     'halfAngle': 20.0,
#     'speed': 577.0,
#     'type': 'C',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'Leading edge measurement using triangulation between SOHO and STEREO Ahead; the CME could not be fit to the far-side.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': 11.0,
#     'submissionTime': '2024-09-24T13:22Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/33561/-1',
#     'enlilList': None}],
#   'linkedEvents': None},
#  {'activityID': '2024-09-25T04:53:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2024-09-25T04:53Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'},
#    {'displayName': 'STEREO A: SECCHI/COR2'}],
#   'sourceLocation': '',
#   'activeRegionNum': None,
#   'note': 'Faint outflow type puff CME to the S/SW in STEREO A COR2 imagery and later frames in SOHO LASCO C3 imagery following a data gap. (Not visible in SOHO LASCO C2 imagery due to data gap). There is no clear source for this CME.',
#   'submissionTime': '2024-09-25T13:24Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/33565/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2024-09-25T13:48Z',
#     'latitude': -47.0,
#     'longitude': 38.0,
#     'halfAngle': 11.0,
#     'speed': 393.0,
#     'type': 'S',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'Parameters based on best fit in SOHO LASCO C3 and STEREO A COR2 imagery.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': 13.5,
#     'submissionTime': '2024-09-25T13:29Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/33566/-1',
#     'enlilList': None}],
#   'linkedEvents': None},
#  {'activityID': '2024-09-26T05:38:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2024-09-26T05:38Z',
#   'instruments': [{'displayName': 'STEREO A: SECCHI/COR2'}],
#   'sourceLocation': 'S35E70',
#   'activeRegionNum': None,
#   'note': 'This CME is visible to the southeast in STEREO A COR2 imagery. It is not visible in SOHO LASCO C2 imagery due to a data gap lasing from 2024-09-26T04:00Z-07:36Z, and the event is obscured by the pylon in SOHO LASCO C3. The source is likely an eruption from S35E70 starting around 2024-09-26T04:00Z as seen in SDO AIA 131, 171, 193, 304 imagery. An opening of field lines is visible over the southeast limb at this time in SDO AIA 171 and 193 as well',
#   'submissionTime': '2024-09-26T17:14Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/33575/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2024-09-26T18:37Z',
#     'latitude': -58.0,
#     'longitude': -70.0,
#     'halfAngle': 33.0,
#     'speed': 261.0,
#     'type': 'S',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'Longitude based on the source location. The measured parameters may vary slightly as there is a data gap in SOHO imagery at the time of this event.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': 8.4,
#     'submissionTime': '2024-09-26T17:16Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/33576/-1',
#     'enlilList': None}],
#   'linkedEvents': None},
#  {'activityID': '2024-09-26T09:36:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2024-09-26T09:36Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'},
#    {'displayName': 'STEREO A: SECCHI/COR2'}],
#   'sourceLocation': '',
#   'activeRegionNum': None,
#   'note': 'This CME is visible to the southwest in SOHO LASCO C2/C3 and STEREO A COR2 imagery. The source is likely far-sided and may be related to filamentary material which is barely visible over/beyond the southwest limb in SDO AIA 304 imagery starting around 2024-08-26T07:40Z. An opening of field lines visible over the southwest limb in GOES SUVI 284 imagery starting around 2024-09-26T10:00Z as well.',
#   'submissionTime': '2024-09-26T17:21Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/33577/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2024-09-26T19:29Z',
#     'latitude': -38.0,
#     'longitude': 134.0,
#     'halfAngle': 49.0,
#     'speed': 415.0,
#     'type': 'S',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'Measurement based on the best fit between SOHO LASCO C3 and STEREO A COR2 imagery. As the source is far-sided and the precise source location is unknown, the measured parameters may vary slightly.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': 14.2,
#     'submissionTime': '2024-09-26T17:25Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/33578/-1',
#     'enlilList': [{'modelCompletionTime': '2024-09-26T17:41Z',
#       'au': 2.0,
#       'estimatedShockArrivalTime': None,
#       'estimatedDuration': None,
#       'rmin_re': None,
#       'kp_18': None,
#       'kp_90': None,
#       'kp_135': None,
#       'kp_180': None,
#       'isEarthGB': False,
#       'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/33581/-1',
#       'impactList': None,
#       'cmeIDs': ['2024-09-26T09:36:00-CME-001']}]}],
#   'linkedEvents': None},
#  {'activityID': '2024-09-26T14:36:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2024-09-26T14:36Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'},
#    {'displayName': 'STEREO A: SECCHI/COR2'}],
#   'sourceLocation': '',
#   'activeRegionNum': None,
#   'note': 'This CME is visible to the northeast in SOHO LASCO C2/C3 imagery. It is faintly visible to the north in STEREO A COR2 imagery. The source is likely far-sided and may be related to faint field line movement visible over the northeast limb in SDO AIA 171 around 2024-09-26T13:00Z.',
#   'submissionTime': '2024-09-26T17:40Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/33579/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2024-09-27T01:44Z',
#     'latitude': 65.0,
#     'longitude': None,
#     'halfAngle': 39.0,
#     'speed': 319.0,
#     'type': 'S',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'Plane-of-sky',
#     'note': 'A plane-of-sky measurement was made using SOHO LASCO C2 imagery as the CME is too faintly observed in STEREO A COR2 to make a reliable measurement using this imagery.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': 5.0,
#     'submissionTime': '2024-09-26T17:44Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/33580/-1',
#     'enlilList': None}],
#   'linkedEvents': None},
#  {'activityID': '2024-09-26T20:00:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2024-09-26T20:00Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'}],
#   'sourceLocation': 'S12E75',
#   'activeRegionNum': 13839,
#   'note': 'This CME is faintly visible to the east in SOHO LASCO C2, C3 and STEREO A COR2 imagery (more easily in difference imagery than white light imagery). The source appears to be a C5.0 flare and filament ejecta from newly numbered AR 3839 in the SE of the Earth-facing disk. The eruption is best seen in SDO/AIA 131 and 304 as well as GOES SUVI 304 imagery starting around 2024-09-26T19:45Z.',
#   'submissionTime': '2024-09-27T01:50Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/33583/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2024-09-27T07:16Z',
#     'latitude': -8.0,
#     'longitude': -75.0,
#     'halfAngle': 30.0,
#     'speed': 324.0,
#     'type': 'S',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'Parameters based on best fit of leading edge in SOHO LASCO C2 and C3 imagery using potential source location. The feature becomes too faint/diffused in later frames to track. No good STEREO A frames to use in measurement.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': 6.2,
#     'submissionTime': '2024-09-27T01:55Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/33584/-1',
#     'enlilList': [{'modelCompletionTime': '2024-09-27T02:11Z',
#       'au': 2.0,
#       'estimatedShockArrivalTime': None,
#       'estimatedDuration': None,
#       'rmin_re': None,
#       'kp_18': None,
#       'kp_90': None,
#       'kp_135': None,
#       'kp_180': None,
#       'isEarthGB': False,
#       'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/33586/-1',
#       'impactList': [{'isGlancingBlow': True,
#         'location': 'Solar Orbiter',
#         'arrivalTime': '2024-09-28T06:00Z'}],
#       'cmeIDs': ['2024-09-26T20:00:00-CME-001']}]}],
#   'linkedEvents': [{'activityID': '2024-09-26T19:41:00-FLR-001'}]},
#  {'activityID': '2024-09-27T09:24:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2024-09-27T09:24Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'},
#    {'displayName': 'STEREO A: SECCHI/COR2'}],
#   'sourceLocation': '',
#   'activeRegionNum': None,
#   'note': 'Disjoint CME seen to the east made up of a southeasterly, wider portion and a northeasterly, jet-like portion. Analysis focuses on the southeasterly portion. May be associated with a minor filament seen near 09:00Z in GOES 304/SDO 304 or activity (moving and opening field lines) associated with active regions that are turning on to the Earth-facing disk.',
#   'submissionTime': '2024-09-27T12:19Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/33587/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2024-09-27T16:07Z',
#     'latitude': -12.0,
#     'longitude': -88.0,
#     'halfAngle': 25.0,
#     'speed': 515.0,
#     'type': 'C',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'Two spacecraft measurement using triangulation of the leading edge to determine a potential longitude; uncertainty in longitude approximately +/- 15 degrees. Was found to likely not be associated with on-disk activity.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': 8.0,
#     'submissionTime': '2024-09-27T12:23Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/33588/-1',
#     'enlilList': [{'modelCompletionTime': '2024-09-27T12:16Z',
#       'au': 2.0,
#       'estimatedShockArrivalTime': None,
#       'estimatedDuration': None,
#       'rmin_re': None,
#       'kp_18': None,
#       'kp_90': None,
#       'kp_135': None,
#       'kp_180': None,
#       'isEarthGB': False,
#       'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/33589/-1',
#       'impactList': [{'isGlancingBlow': False,
#         'location': 'Solar Orbiter',
#         'arrivalTime': '2024-09-28T08:06Z'},
#        {'isGlancingBlow': True,
#         'location': 'OSIRIS-APEX',
#         'arrivalTime': '2024-09-29T17:00Z'}],
#       'cmeIDs': ['2024-09-27T09:24:00-CME-001']}]}],
#   'linkedEvents': None},
#  {'activityID': '2024-09-28T06:36:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2024-09-28T06:36Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'},
#    {'displayName': 'STEREO A: SECCHI/COR2'}],
#   'sourceLocation': '',
#   'activeRegionNum': None,
#   'note': 'Faint hollow loop CME seen to the SE in SOHO LASCO C2/C3 and STEREO A COR2. The exact source is elusive. There has been continuous gentle field line movement on the SE limb over the course of several hours around this time, which may have possibly released some material. STEREO A is in campaign mode for the Parker Solar Probe perihelion pass, affecting COR2A image cadence and quality.',
#   'submissionTime': '2024-09-28T19:58Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/33593/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2024-09-28T17:18Z',
#     'latitude': -56.0,
#     'longitude': -38.0,
#     'halfAngle': 27.0,
#     'speed': 481.0,
#     'type': 'S',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'Best fit measurement between C2/C3 and COR2A. Leading edge accelerates in C2. STEREO A is in campaign mode for the Parker Solar Probe perihelion pass, affecting COR2A image cadence and quality.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': 14.0,
#     'submissionTime': '2024-09-28T20:00Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/33594/-1',
#     'enlilList': None}],
#   'linkedEvents': None},
#  {'activityID': '2024-09-28T11:00:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2024-09-28T11:00Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'},
#    {'displayName': 'STEREO A: SECCHI/COR2'}],
#   'sourceLocation': 'S15W35',
#   'activeRegionNum': 13834,
#   'note': 'Narrow CME visible to the SW in SOHO LASCO C2/C3 and STEREO A COR2. The potential source is an eruption seen in SDO AIA 193 starting at 2024-09-28T10:27Z, also visible in STEREO A EUV 195, around S15W35, from AR 3834. There is also field line movement seen beyond the west limb in STEREO A EUV 195 and SDO AIA 171/193 starting at 2024-09-28T10:48Z, which may be from a separate eruption on the far side.',
#   'submissionTime': '2024-09-28T23:15Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/33595/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2024-09-29T01:36Z',
#     'latitude': -28.0,
#     'longitude': 54.0,
#     'halfAngle': 14.0,
#     'speed': 250.0,
#     'type': 'S',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'Measurement based on SOHO LASCO C2/C3 and limited available frames of STEREO A COR2 imagery due to ongoing STEREO A campaign.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': 7.3,
#     'submissionTime': '2024-09-28T23:16Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/33596/-1',
#     'enlilList': None}],
#   'linkedEvents': None},
#  {'activityID': '2024-09-28T17:00:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2024-09-28T17:00Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'},
#    {'displayName': 'STEREO A: SECCHI/COR2'}],
#   'sourceLocation': '',
#   'activeRegionNum': None,
#   'note': 'CME visible to the east in SOHO LASCO C2/C3 and STEREO A COR2. The potential source can be seen as opening field lines best seen in SDO AIA 171 in ISWA starting at 2024-09-28T16:09Z. Some brightening can be seen on the disk in SDO AIA 193 around S15E75 as well. The start of the CME is obscured by a data gap in STEREO A COR2 at 2024-09-28T14:09Z-20:09Z.',
#   'submissionTime': '2024-09-29T00:22Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/33597/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2024-09-29T05:31Z',
#     'latitude': 5.0,
#     'longitude': None,
#     'halfAngle': 26.0,
#     'speed': 292.0,
#     'type': 'S',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'Plane-of-sky',
#     'note': 'Plane of sky measurement using SOHO LASCO C2/C3 in SWPC_CAT due to unclear source location near the east limb. No STEREO A COR2 difference imagery was available for a measurement.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': 9.6,
#     'submissionTime': '2024-09-29T00:23Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/33598/-1',
#     'enlilList': None}],
#   'linkedEvents': None},
#  {'activityID': '2024-09-29T06:00:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2024-09-29T06:00Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'},
#    {'displayName': 'STEREO A: SECCHI/COR2'}],
#   'sourceLocation': 'S15W42',
#   'activeRegionNum': 13834,
#   'note': 'Narrow, fast eruption seen to the southwest in SOHO C2 and due west in STEREO A COR2, accompanied by a much wider, faint shock seen to the northwest in SOHO C2/C3. Appears to be associated with an eruption near AR3834 (S15W42) seen in SDO 193/171 around 2024-09-29T05:15Z.',
#   'submissionTime': '2024-09-29T15:52Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/33608/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2024-09-29T08:42Z',
#     'latitude': -14.0,
#     'longitude': 46.0,
#     'halfAngle': 19.0,
#     'speed': 1148.0,
#     'type': 'O',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'Leading edge measurement using SOHO C2, C3 and limited STEREO A COR2 frames, as the spacecraft was in a campaign. There appears to be some westward deflection.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': 18.0,
#     'submissionTime': '2024-09-29T15:56Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/33609/-1',
#     'enlilList': [{'modelCompletionTime': '2024-09-29T15:36Z',
#       'au': 2.0,
#       'estimatedShockArrivalTime': None,
#       'estimatedDuration': None,
#       'rmin_re': None,
#       'kp_18': None,
#       'kp_90': None,
#       'kp_135': None,
#       'kp_180': None,
#       'isEarthGB': False,
#       'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/33610/-1',
#       'impactList': [{'isGlancingBlow': False,
#         'location': 'Mars',
#         'arrivalTime': '2024-10-02T20:44Z'},
#        {'isGlancingBlow': False,
#         'location': 'STEREO A',
#         'arrivalTime': '2024-10-01T05:00Z'}],
#       'cmeIDs': ['2024-09-29T06:00:00-CME-001']},
#      {'modelCompletionTime': '2024-09-29T15:58Z',
#       'au': 5.5,
#       'estimatedShockArrivalTime': None,
#       'estimatedDuration': None,
#       'rmin_re': None,
#       'kp_18': None,
#       'kp_90': None,
#       'kp_135': None,
#       'kp_180': None,
#       'isEarthGB': False,
#       'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/33611/-1',
#       'impactList': [{'isGlancingBlow': False,
#         'location': 'Mars',
#         'arrivalTime': '2024-10-02T20:08Z'},
#        {'isGlancingBlow': False,
#         'location': 'Juno',
#         'arrivalTime': '2024-10-14T00:00Z'},
#        {'isGlancingBlow': False,
#         'location': 'STEREO A',
#         'arrivalTime': '2024-10-01T05:00Z'}],
#       'cmeIDs': ['2024-09-29T06:00:00-CME-001']}]}],
#   'linkedEvents': [{'activityID': '2024-09-29T05:26:00-FLR-001'}]},
#  {'activityID': '2024-09-29T08:36:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2024-09-29T08:36Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'},
#    {'displayName': 'STEREO A: SECCHI/COR2'}],
#   'sourceLocation': '',
#   'activeRegionNum': None,
#   'note': 'Lightbulb CME seen to the ENE in SOHO C2 and STEREO COR2A; associated with strongly opening magnetic field lines off/behind the NE limb seen best in SDO 171/193 and GOES 284 around 2024-09-29T08:00Z.',
#   'submissionTime': '2024-09-29T13:30Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/33600/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2024-09-29T15:02Z',
#     'latitude': 15.0,
#     'longitude': -119.0,
#     'halfAngle': 39.0,
#     'speed': 503.0,
#     'type': 'C',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'Two spacecraft leading edge measurement using limited STEREO A frames due to an ongoing campaign.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': 15.0,
#     'submissionTime': '2024-09-29T13:32Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/33601/-1',
#     'enlilList': [{'modelCompletionTime': '2024-09-29T13:20Z',
#       'au': 2.0,
#       'estimatedShockArrivalTime': None,
#       'estimatedDuration': None,
#       'rmin_re': None,
#       'kp_18': None,
#       'kp_90': None,
#       'kp_135': None,
#       'kp_180': None,
#       'isEarthGB': False,
#       'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/33602/-1',
#       'impactList': [{'isGlancingBlow': False,
#         'location': 'OSIRIS-APEX',
#         'arrivalTime': '2024-10-01T06:19Z'},
#        {'isGlancingBlow': False,
#         'location': 'Solar Orbiter',
#         'arrivalTime': '2024-09-30T04:07Z'}],
#       'cmeIDs': ['2024-09-29T08:36:00-CME-001']}]}],
#   'linkedEvents': None},
#  {'activityID': '2024-09-29T18:12:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2024-09-29T18:12Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'}],
#   'sourceLocation': '',
#   'activeRegionNum': None,
#   'note': 'Narrow, bright, and slow CME seen to the WNW in SOHO C2 during a STEREO A COR2 data gap/campaign. Appears to be associated with with a very slow/minor eruption emanating from field lines above the western limb, seen best in GOES 284, SDO 193, SDO 171 and SDO 304 around 2024-09-29T18:00Z.',
#   'submissionTime': '2024-09-29T19:36Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/33615/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2024-09-30T07:29Z',
#     'latitude': 24.0,
#     'longitude': None,
#     'halfAngle': 17.0,
#     'speed': 275.0,
#     'type': 'S',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'Plane-of-sky',
#     'note': 'Preliminary SOHO C2 plane of sky measurement using early frames.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': 4.0,
#     'submissionTime': '2024-09-29T19:39Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/33616/-1',
#     'enlilList': None}],
#   'linkedEvents': None},
#  {'activityID': '2024-09-30T03:12:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2024-09-30T03:12Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'},
#    {'displayName': 'STEREO A: SECCHI/COR2'}],
#   'sourceLocation': '',
#   'activeRegionNum': None,
#   'note': 'Flux rope CME seen to the E/NE in SOHO LASCO C2, C3 and STEREO A COR2. A wider faint possibly shock-like feature is seen preceding the leading edge. Source is opening field lines beyond the E limb seen starting at 2024-09-30T02:45Z in SDO AIA 171/193.',
#   'submissionTime': '2024-09-30T13:44Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/33617/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2024-09-30T08:42Z',
#     'latitude': 9.0,
#     'longitude': -131.0,
#     'halfAngle': 40.0,
#     'speed': 637.0,
#     'type': 'C',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'Measurement made using best fit between COR2A, abundant frames of C3, and a few frames of C2. STEREO A is currently in campaign mode for the Parker Solar Probe perihelion pass.',
#     'levelOfData': 1,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': 22.0,
#     'submissionTime': '2024-09-30T13:45Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/33618/-1',
#     'enlilList': [{'modelCompletionTime': '2024-09-30T13:49Z',
#       'au': 2.0,
#       'estimatedShockArrivalTime': None,
#       'estimatedDuration': None,
#       'rmin_re': None,
#       'kp_18': None,
#       'kp_90': None,
#       'kp_135': None,
#       'kp_180': None,
#       'isEarthGB': False,
#       'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/33619/-1',
#       'impactList': [{'isGlancingBlow': False,
#         'location': 'OSIRIS-APEX',
#         'arrivalTime': '2024-10-01T19:03Z'},
#        {'isGlancingBlow': False,
#         'location': 'Solar Orbiter',
#         'arrivalTime': '2024-09-30T20:56Z'}],
#       'cmeIDs': ['2024-09-30T03:12:00-CME-001']},
#      {'modelCompletionTime': '2024-09-30T14:12Z',
#       'au': 5.5,
#       'estimatedShockArrivalTime': None,
#       'estimatedDuration': None,
#       'rmin_re': None,
#       'kp_18': None,
#       'kp_90': None,
#       'kp_135': None,
#       'kp_180': None,
#       'isEarthGB': False,
#       'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/33620/-1',
#       'impactList': [{'isGlancingBlow': False,
#         'location': 'OSIRIS-APEX',
#         'arrivalTime': '2024-10-01T18:21Z'},
#        {'isGlancingBlow': False,
#         'location': 'Solar Orbiter',
#         'arrivalTime': '2024-09-30T20:42Z'}],
#       'cmeIDs': ['2024-09-30T03:12:00-CME-001']},
#      {'modelCompletionTime': '2024-10-01T17:00Z',
#       'au': 2.0,
#       'estimatedShockArrivalTime': None,
#       'estimatedDuration': None,
#       'rmin_re': None,
#       'kp_18': None,
#       'kp_90': None,
#       'kp_135': None,
#       'kp_180': None,
#       'isEarthGB': False,
#       'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/33651/-1',
#       'impactList': [{'isGlancingBlow': False,
#         'location': 'OSIRIS-APEX',
#         'arrivalTime': '2024-10-01T19:40Z'},
#        {'isGlancingBlow': False,
#         'location': 'Solar Orbiter',
#         'arrivalTime': '2024-09-30T21:16Z'}],
#       'cmeIDs': ['2024-09-30T03:12:00-CME-001',
#        '2024-09-30T07:12:00-CME-001']}]}],
#   'linkedEvents': None},
#  {'activityID': '2024-09-30T05:36:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2024-09-30T05:36Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'},
#    {'displayName': 'STEREO A: SECCHI/COR2'}],
#   'sourceLocation': 'S20E40',
#   'activeRegionNum': 13834,
#   'note': 'Narrow faint CME to the southwest. Its source is uncertain, but possibly is this small area of opening field lines at about 05:20Z seen at S20E40 near AR 3834.',
#   'submissionTime': '2024-10-01T01:06Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/33632/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2024-09-30T13:33Z',
#     'latitude': -30.0,
#     'longitude': 54.0,
#     'halfAngle': 14.0,
#     'speed': 433.0,
#     'type': 'S',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'Approximate analysis based on the fit with two coronagraphs, confirmed by the source.',
#     'levelOfData': 1,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': None,
#     'submissionTime': '2024-10-01T15:18Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/33633/-1',
#     'enlilList': [{'modelCompletionTime': '2024-10-01T00:43Z',
#       'au': 2.0,
#       'estimatedShockArrivalTime': None,
#       'estimatedDuration': None,
#       'rmin_re': None,
#       'kp_18': None,
#       'kp_90': None,
#       'kp_135': None,
#       'kp_180': None,
#       'isEarthGB': False,
#       'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/33631/-1',
#       'impactList': [{'isGlancingBlow': False,
#         'location': 'Mars',
#         'arrivalTime': '2024-10-03T14:32Z'},
#        {'isGlancingBlow': True,
#         'location': 'STEREO A',
#         'arrivalTime': '2024-10-02T13:30Z'}],
#       'cmeIDs': ['2024-09-30T05:36:00-CME-001',
#        '2024-09-30T16:12:00-CME-001']},
#      {'modelCompletionTime': '2024-10-01T01:06Z',
#       'au': 5.5,
#       'estimatedShockArrivalTime': None,
#       'estimatedDuration': None,
#       'rmin_re': None,
#       'kp_18': None,
#       'kp_90': None,
#       'kp_135': None,
#       'kp_180': None,
#       'isEarthGB': False,
#       'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/33636/-1',
#       'impactList': [{'isGlancingBlow': False,
#         'location': 'Mars',
#         'arrivalTime': '2024-10-03T13:59Z'},
#        {'isGlancingBlow': False,
#         'location': 'Juno',
#         'arrivalTime': '2024-10-15T00:00Z'},
#        {'isGlancingBlow': True,
#         'location': 'STEREO A',
#         'arrivalTime': '2024-10-02T13:30Z'}],
#       'cmeIDs': ['2024-09-30T05:36:00-CME-001',
#        '2024-09-30T16:12:00-CME-001']}]}],
#   'linkedEvents': None},
#  {'activityID': '2024-09-30T07:12:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2024-09-30T07:12Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'},
#    {'displayName': 'STEREO A: SECCHI/COR2'}],
#   'sourceLocation': '',
#   'activeRegionNum': None,
# ...
#    {'displayName': 'STEREO A: SECCHI/COR2'}],
#   'sourceLocation': 'N30E25',
#   'activeRegionNum': None,
#   'note': 'A loop like CME to the northeast following a narrower 2024-10-17T07:36Z CME. The source could be the filament eruption seen in SDO AIA imagery spanning from about N30E10 to N40E50. Movement and liftoff of the filamentary material can be seen in SDO AIA 304/171/193 and GOES SUVI 304/284 lasting from about 2024-10-17T06:00Z-07:30Z, so this may be the source of both CME:2024-10-17T07:36Z and CME:2024-10-17T08:36Z.',
#   'submissionTime': '2024-10-17T13:53Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34046/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2024-10-17T17:39Z',
#     'latitude': 34.0,
#     'longitude': -26.0,
#     'halfAngle': 19.0,
#     'speed': 374.0,
#     'type': 'S',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'Analysis based on the fit in two coronagraph and confirmed by the location of the source (the larger, central, part of the filament eruption).',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': None,
#     'submissionTime': '2024-10-17T13:55Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34048/-1',
#     'enlilList': [{'modelCompletionTime': '2024-10-17T13:56Z',
#       'au': 2.0,
#       'estimatedShockArrivalTime': None,
#       'estimatedDuration': None,
#       'rmin_re': None,
#       'kp_18': None,
#       'kp_90': None,
#       'kp_135': None,
#       'kp_180': None,
#       'isEarthGB': False,
#       'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/34049/-1',
#       'impactList': None,
#       'cmeIDs': ['2024-10-17T07:36:00-CME-001',
#        '2024-10-17T08:36:00-CME-001']}]}],
#   'linkedEvents': None},
#  {'activityID': '2024-10-17T23:12:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2024-10-17T23:12Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'},
#    {'displayName': 'STEREO A: SECCHI/COR2'}],
#   'sourceLocation': 'N01E90',
#   'activeRegionNum': None,
#   'note': 'Jet-like, narrow CME seen out to a few solar radii first at 2024-10-17T23:12Z to the east after SOHO and STEREO A data refilled but the start time is earlier than this; possibly associated with a minor eruption near or just beyond the eastern limb as seen in SDO 171 and GOES 284 with northward deflection.',
#   'submissionTime': '2024-10-18T00:46Z',
#   'versionId': 2,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34060/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2024-10-18T06:12Z',
#     'latitude': 15.0,
#     'longitude': -85.0,
#     'halfAngle': 10.0,
#     'speed': 489.0,
#     'type': 'S',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'Updated measurement to a few more solar radii.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': 8.0,
#     'submissionTime': '2024-10-18T01:14Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34063/-1',
#     'enlilList': [{'modelCompletionTime': '2024-10-18T01:40Z',
#       'au': 2.0,
#       'estimatedShockArrivalTime': None,
#       'estimatedDuration': None,
#       'rmin_re': None,
#       'kp_18': None,
#       'kp_90': None,
#       'kp_135': None,
#       'kp_180': None,
#       'isEarthGB': False,
#       'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/34064/-1',
#       'impactList': [{'isGlancingBlow': False,
#         'location': 'Parker Solar Probe',
#         'arrivalTime': '2024-10-19T18:00Z'}],
#       'cmeIDs': ['2024-10-17T23:12:00-CME-001']}]},
#    {'isMostAccurate': False,
#     'time21_5': '2024-10-18T07:21Z',
#     'latitude': 17.0,
#     'longitude': -85.0,
#     'halfAngle': 10.0,
#     'speed': 417.0,
#     'type': 'S',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'Measurement of the leading edge out to a few solar radii using STEREO A and SOHO imagery to triangulate the leading edge.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': 5.0,
#     'submissionTime': '2024-10-18T00:46Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34061/-1',
#     'enlilList': [{'modelCompletionTime': '2024-10-18T00:38Z',
#       'au': 2.0,
#       'estimatedShockArrivalTime': None,
#       'estimatedDuration': None,
#       'rmin_re': None,
#       'kp_18': None,
#       'kp_90': None,
#       'kp_135': None,
#       'kp_180': None,
#       'isEarthGB': False,
#       'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/34062/-1',
#       'impactList': [{'isGlancingBlow': False,
#         'location': 'Parker Solar Probe',
#         'arrivalTime': '2024-10-19T20:00Z'}],
#       'cmeIDs': ['2024-10-17T23:12:00-CME-001']}]}],
#   'linkedEvents': None},
#  {'activityID': '2024-10-18T11:36:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2024-10-18T11:36Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'},
#    {'displayName': 'STEREO A: SECCHI/COR2'}],
#   'sourceLocation': '',
#   'activeRegionNum': None,
#   'note': 'Faint CME with a fuzzy front, preceded and followed by outflows and following the slow/faint 2024-10-18T06:12Z CME. The start time of this event can be a bit earlier. The source is possibly a very minor faint eruption with ejecta/movement of field lines seen on/behind the NW limb in AIA 193/171 starting at 2024-10-18T11:30Z.',
#   'submissionTime': '2024-10-18T18:42Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34070/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2024-10-18T23:37Z',
#     'latitude': 36.0,
#     'longitude': 102.0,
#     'halfAngle': 29.0,
#     'speed': 305.0,
#     'type': 'S',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'A very approximate measurement based on the fit with two coronagraphs. The source is likely behind the limb and the fit gives a range of possible longitudes. Additionally, the front is very fuzzy.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': None,
#     'submissionTime': '2024-10-18T18:44Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34071/-1',
#     'enlilList': [{'modelCompletionTime': '2024-10-18T18:47Z',
#       'au': 2.0,
#       'estimatedShockArrivalTime': None,
#       'estimatedDuration': None,
#       'rmin_re': None,
#       'kp_18': None,
#       'kp_90': None,
#       'kp_135': None,
#       'kp_180': None,
#       'isEarthGB': False,
#       'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/34074/-1',
#       'impactList': None,
#       'cmeIDs': ['2024-10-18T11:36:00-CME-001']}]}],
#   'linkedEvents': None},
#  {'activityID': '2024-10-19T07:12:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2024-10-19T07:12Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'}],
#   'sourceLocation': 'S03W82',
#   'activeRegionNum': 13854,
#   'note': 'Faint diffuse CME to the W/SW in SOHO LASCO C2, C3 (barely visible), and possibly STEREO A COR2 imagery (unclear if feature seen to the west in STA is outflow or this CME). This CME is likely associated with the M6.5 flare from AR13854 (S03W82) peaking at 2024-10-19T06:56Z best seen in SDO/AIA 131. A filament to the north of the AR begins to erupt around 2024-10-19T06:24Z as seen in SDO/AIA 304 and appears to lift off with the flare and may be associated with this CME as well.',
#   'submissionTime': '2024-10-19T15:16Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34080/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2024-10-19T20:41Z',
#     'latitude': -9.0,
#     'longitude': 82.0,
#     'halfAngle': 21.0,
#     'speed': 275.0,
#     'type': 'S',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'These parameters are based on the source location of the M6.5 flare. The CME features are not visible in SOHO LASCO C3 and STEREO A COR2 difference imagery. Due to single spacecraft mode, there is a larger amount of uncertainty with this measurement.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': 6.0,
#     'submissionTime': '2024-10-19T15:17Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34081/-1',
#     'enlilList': None}],
#   'linkedEvents': [{'activityID': '2024-10-19T06:48:00-FLR-001'}]},
#  {'activityID': '2024-10-19T09:24:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2024-10-19T09:24Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'},
#    {'displayName': 'STEREO A: SECCHI/COR2'}],
#   'sourceLocation': 'S10E65',
#   'activeRegionNum': 13863,
#   'note': 'This CME is visible to the E/NE in SOHO LASCO C2, C3, and STEREO A COR2 imagery. The source appears to be an eruption from AR 3863 starting around 2024-10-19T09:00Z in SDO/AIA 304/171/211/94. Moving/opening field lines are visible in the SE of SDO/AIA 171, however it is not clear if these moving/opening field lines are associated with this eruption or another eruption that may be associated with the CME first seen in SOHO LASCO C2 at 2024-10-19T09:48Z to the SE.',
#   'submissionTime': '2024-10-19T18:25Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34082/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2024-10-19T13:03Z',
#     'latitude': 19.0,
#     'longitude': -73.0,
#     'halfAngle': 34.0,
#     'speed': 1015.0,
#     'type': 'O',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'Parameters based on best fit of features in SOHO LASCO C3 and STEREO A COR2 imagery.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': 14.4,
#     'submissionTime': '2024-10-19T18:26Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34083/-1',
#     'enlilList': [{'modelCompletionTime': '2024-10-19T18:47Z',
#       'au': 2.0,
#       'estimatedShockArrivalTime': None,
#       'estimatedDuration': None,
#       'rmin_re': None,
#       'kp_18': None,
#       'kp_90': None,
#       'kp_135': None,
#       'kp_180': None,
#       'isEarthGB': False,
#       'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/34084/-1',
#       'impactList': [{'isGlancingBlow': False,
#         'location': 'Parker Solar Probe',
#         'arrivalTime': '2024-10-20T09:29Z'},
#        {'isGlancingBlow': True,
#         'location': 'Lucy',
#         'arrivalTime': '2024-10-21T16:00Z'},
#        {'isGlancingBlow': True,
#         'location': 'OSIRIS-APEX',
#         'arrivalTime': '2024-10-21T04:00Z'},
#        {'isGlancingBlow': True,
#         'location': 'Solar Orbiter',
#         'arrivalTime': '2024-10-20T14:00Z'}],
#       'cmeIDs': ['2024-10-19T09:24:00-CME-001']}]}],
#   'linkedEvents': None},
#  {'activityID': '2024-10-19T09:48:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2024-10-19T09:48Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'},
#    {'displayName': 'STEREO A: SECCHI/COR2'}],
#   'sourceLocation': '',
#   'activeRegionNum': None,
#   'note': 'Narrow CME to the south. A potential source could be the opening of field lines to the S/SE in SDO/AIA 171 around 2024-10-19T09Z.',
#   'submissionTime': '2024-10-19T20:23Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34087/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2024-10-19T14:31Z',
#     'latitude': -64.0,
#     'longitude': -148.0,
#     'halfAngle': 14.0,
#     'speed': 708.0,
#     'type': 'C',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'Analysis based on the best fit with two coronagraphs. Only backsided longitude and high southern latitude produce a fit.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': None,
#     'submissionTime': '2024-10-19T20:25Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34088/-1',
#     'enlilList': None}],
#   'linkedEvents': None},
#  {'activityID': '2024-10-19T19:00:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2024-10-19T19:00Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'},
#    {'displayName': 'STEREO A: SECCHI/COR2'}],
#   'sourceLocation': '',
#   'activeRegionNum': None,
#   'note': 'Narrow faint CME with a dimpled front. The likely source is a minor movement of field line behind the northwest limb at latitude ~20 seen starting around 2024-10-19T17:40Z in AIA 193/171.',
#   'submissionTime': '2024-10-19T23:43Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34089/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2024-10-20T04:27Z',
#     'latitude': 25.0,
#     'longitude': 124.0,
#     'halfAngle': 15.0,
#     'speed': 364.0,
#     'type': 'S',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': "Approximate analysis based on the fit in two coronagraphs. The source is behind the limb and the front is faint and diffuse. Not simulated because there are no missions in the CME's path.",
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': None,
#     'submissionTime': '2024-10-19T23:46Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34090/-1',
#     'enlilList': None}],
#   'linkedEvents': None},
#  {'activityID': '2024-10-19T22:36:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2024-10-19T22:36Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'},
#    {'displayName': 'STEREO A: SECCHI/COR2'}],
#   'sourceLocation': '',
#   'activeRegionNum': None,
#   'note': 'Minor faint CME to the southeast, becoming wider with time, consisting of a faint shock on its sides. The source for this eruption appears to be movement/opening of field lines just behind the SE limb (lat ~-20) seen around 2024-10-19T22:30Z.',
#   'submissionTime': '2024-10-20T14:34Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34091/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2024-10-20T08:19Z',
#     'latitude': -36.0,
#     'longitude': -104.0,
#     'halfAngle': 31.0,
#     'speed': 466.0,
#     'type': 'S',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'Two spacecraft leading edge measurement to approximate longitude; longitude parameter has uncertainty of about +/- 15 degrees.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': 11.0,
#     'submissionTime': '2024-10-20T14:37Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34092/-1',
#     'enlilList': [{'modelCompletionTime': '2024-10-20T14:27Z',
#       'au': 2.0,
#       'estimatedShockArrivalTime': None,
#       'estimatedDuration': None,
#       'rmin_re': None,
#       'kp_18': None,
#       'kp_90': None,
#       'kp_135': None,
#       'kp_180': None,
#       'isEarthGB': False,
#       'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/34093/-1',
#       'impactList': [{'isGlancingBlow': False,
#         'location': 'OSIRIS-APEX',
#         'arrivalTime': '2024-10-22T15:00Z'},
#        {'isGlancingBlow': True,
#         'location': 'Lucy',
#         'arrivalTime': '2024-10-21T15:00Z'},
#        {'isGlancingBlow': True,
#         'location': 'Parker Solar Probe',
#         'arrivalTime': '2024-10-21T22:00Z'}],
#       'cmeIDs': ['2024-10-19T22:36:00-CME-001']}]}],
#   'linkedEvents': None}]

# %%
# Preview the first result in JSON format
# Use json.dumps with argument indent=4 to format data
print(json.dumps(cme_json, indent=4))
# Out:
# [
#     {
#         "activityID": "2024-09-21T11:12:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-09-21T11:12Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             },
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "note": "Thin diffuse CME seen to the NW in all coronagraphs. The source is best observed in SDO AIA 171 as field line movement on or just beyond the NW limb starting around 2024-09-21T10:39Z.",
#         "submissionTime": "2024-09-21T20:17Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/33526/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-09-21T17:07Z",
#                 "latitude": 29.0,
#                 "longitude": 99.0,
#                 "halfAngle": 10.0,
#                 "speed": 651.0,
#                 "type": "C",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Triangulated measurement between SOHO LASCO C2/C3 and STEREO COR2A, with the source observed in SDO on/near the NW limb.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": 12.7,
#                 "submissionTime": "2024-09-21T20:18Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/33527/-1",
#                 "enlilList": null
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2024-09-21T16:12:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-09-21T16:12Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             },
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "note": "CME visible to the NE in SOHO LASCO C2/C3 and STEREO A COR2. The source is believed to be backsided, with field line movement visible beyond the east limb in GOES SUVI 284 and SDO AIA 171 starting around 2024-09-21T15:00Z.",
#         "submissionTime": "2024-09-23T15:16Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/33535/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-09-22T08:18Z",
#                 "latitude": 71.0,
#                 "longitude": -107.0,
#                 "halfAngle": 38.0,
#                 "speed": 268.0,
#                 "type": "S",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Best fit measurement using several frames of SOHO LASCO C2/C3 and STEREO A COR2 and a farsided source location as observed in EUV imagery.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": 12.0,
#                 "submissionTime": "2024-09-23T15:17Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/33536/-1",
#                 "enlilList": null
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2024-09-21T20:00:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-09-21T20:00Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             }
#         ],
#         "sourceLocation": "N25W80",
#         "activeRegionNum": null,
#         "note": "Narrow CME seen to the NW in SOHO LASCO C2/C3. Not visible in STEREO A COR2 due to a data gap from 2024-09-21T16:53Z-23:09Z.The source is a narrow eruption from N25W80 at 2024-09-21T19:24Z. Ejecta and brightening seen in SDO AIA 304/131. Opening field lines and ejecta seen in SDO AIA 171. Faint dimming seen extending a bit further onto the disk at 19:44Z in SDO AIA 193.",
#         "submissionTime": "2024-09-23T15:53Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/33542/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-09-22T02:17Z",
#                 "latitude": 55.0,
#                 "longitude": 80.0,
#                 "halfAngle": 10.0,
#                 "speed": 561.0,
#                 "type": "C",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Measurement based on source location using SOHO LASCO C2 imagery.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": 7.0,
#                 "submissionTime": "2024-09-23T15:54Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/33543/-1",
#                 "enlilList": null
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2024-09-22T07:12:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-09-22T07:12Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             },
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "note": "CME visible to the NW in SOHO LASCO C2/C3 and STEREO A COR2. The source is best seen in STEREO A EUV 195 as opening field lines starting around 2024-09-22T05:25Z.",
#         "submissionTime": "2024-09-23T17:56Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/33548/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-09-22T20:37Z",
#                 "latitude": 19.0,
#                 "longitude": 136.0,
#                 "halfAngle": 17.0,
#                 "speed": 255.0,
#                 "type": "S",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Measurement based on best fit between SOHO LASCO C2/C3 and STEREO A COR2 in SWPC_CAT as well as source location beyond west limb.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": 9.7,
#                 "submissionTime": "2024-09-23T17:57Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/33549/-1",
#                 "enlilList": [
#                     {
#                         "modelCompletionTime": "2024-09-23T18:37Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": null,
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": null,
#                         "kp_135": null,
#                         "kp_180": null,
#                         "isEarthGB": false,
#                         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/33553/-1",
#                         "impactList": null,
#                         "cmeIDs": [
#                             "2024-09-22T07:12:00-CME-001"
#                         ]
#                     }
#                 ]
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2024-09-22T14:48:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-09-22T14:48Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             },
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "note": "Narrow CME visible to the NW in SOHO LASCO C2/C3 and STEREO A COR2. The source is unclear, and may be beyond the west limb.",
#         "submissionTime": "2024-09-23T15:34Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/33540/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-09-22T22:51Z",
#                 "latitude": 34.0,
#                 "longitude": null,
#                 "halfAngle": 13.0,
#                 "speed": 470.0,
#                 "type": "S",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "Plane-of-sky",
#                 "note": "This CME was not clearly measurable using STEREO A COR2 due to poor quality difference imagery, so a plane of sky measurement using SOHO difference imagery in SWPC_CAT was taken.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": 7.2,
#                 "submissionTime": "2024-09-23T15:35Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/33541/-1",
#                 "enlilList": null
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2024-09-22T19:12:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-09-22T19:12Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             }
#         ],
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "note": "Narrow CME first seen in the NW by SOHO LASCO C2 beginning at 2024-09-22T19:12Z, as well as by SOHO LASCO C3 in later frames. There is no STEREO A COR2 imagery available for this event due to a data gap beginning at 2024-09-22T17:38Z. The source of this eruption is likely far sided, evidenced by field line movement seen beyond the NW limb in SDO AIA 171 around 2024-09-22T19:00Z.",
#         "submissionTime": "2024-09-23T15:26Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/33537/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-09-23T01:50Z",
#                 "latitude": 35.0,
#                 "longitude": 95.0,
#                 "halfAngle": 15.0,
#                 "speed": 537.0,
#                 "type": "C",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Measurement using source location just beyond the limb and SOHO imagery only due to STEREO A COR2 data gap.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": 9.9,
#                 "submissionTime": "2024-09-23T15:27Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/33538/-1",
#                 "enlilList": [
#                     {
#                         "modelCompletionTime": "2024-09-22T23:25Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": null,
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": null,
#                         "kp_135": null,
#                         "kp_180": null,
#                         "isEarthGB": false,
#                         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/33539/-1",
#                         "impactList": null,
#                         "cmeIDs": [
#                             "2024-09-22T19:12:00-CME-001"
#                         ]
#                     }
#                 ]
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2024-09-22T21:36:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-09-22T21:36Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             },
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "sourceLocation": "S23E65",
#         "activeRegionNum": 13835,
#         "note": "CME first seen in the SW by SOHO LASCO C2 beginning at 2024-09-22T21:36Z. The source of this event is an M3.7 flare and filament eruption from S23E65 beginning at 2024-09-22T21:12Z. This flare is seen clearly in SDO AIA 94 and 131, and the filament material is seen best in SDO AIA 304. Field line opening is also visible in SDO AIA 171, 193, and GOES SUVI 284 along with post eruptive arcades visible in SDO AIA 94 and 131. This filament appears to deflect towards the SW as it progresses as seen in GOES SUVI 304. A faint EUV wave seen in SDO AIA 193 also appears to expand more to the west.",
#         "submissionTime": "2024-09-23T14:31Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/33529/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-09-23T00:27Z",
#                 "latitude": -41.0,
#                 "longitude": -25.0,
#                 "halfAngle": 37.0,
#                 "speed": 1239.0,
#                 "type": "O",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Measurement of the bulk of the CME based on best fit between SOHO LASCO C2/C3 and STEREO A COR2 in SWPC_CAT.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": 15.2,
#                 "submissionTime": "2024-09-23T14:44Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/33530/-1",
#                 "enlilList": [
#                     {
#                         "modelCompletionTime": "2024-09-23T01:28Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": "2024-09-25T18:00Z",
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": 3,
#                         "kp_135": 4,
#                         "kp_180": 5,
#                         "isEarthGB": true,
#                         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/33531/-1",
#                         "impactList": [
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "Lucy",
#                                 "arrivalTime": "2024-09-25T10:00Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "STEREO A",
#                                 "arrivalTime": "2024-09-26T02:00Z"
#                             }
#                         ],
#                         "cmeIDs": [
#                             "2024-09-22T21:36:00-CME-001"
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-09-23T00:04Z",
#                 "latitude": -18.0,
#                 "longitude": -24.0,
#                 "halfAngle": 45.0,
#                 "speed": 1381.0,
#                 "type": "O",
#                 "featureCode": "SH",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Measurement of the wider, fainter, SHOCK of the CME.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": 17.4,
#                 "submissionTime": "2024-09-23T14:43Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/33532/-1",
#                 "enlilList": [
#                     {
#                         "modelCompletionTime": "2024-09-23T11:50Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": "2024-09-24T18:55Z",
#                         "estimatedDuration": 28.5,
#                         "rmin_re": 5.4,
#                         "kp_18": null,
#                         "kp_90": 6,
#                         "kp_135": 8,
#                         "kp_180": 8,
#                         "isEarthGB": false,
#                         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/33533/-1",
#                         "impactList": [
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "Lucy",
#                                 "arrivalTime": "2024-09-24T14:29Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "STEREO A",
#                                 "arrivalTime": "2024-09-25T02:00Z"
#                             }
#                         ],
#                         "cmeIDs": [
#                             "2024-09-22T21:36:00-CME-001"
#                         ]
#                     }
#                 ]
#             }
#         ],
#         "linkedEvents": [
#             {
#                 "activityID": "2024-09-22T21:12:00-FLR-001"
#             }
#         ]
#     },
#     {
#         "activityID": "2024-09-23T02:00:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-09-23T02:00Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             }
#         ],
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "note": "CME visible to the NW in SOHO LASCO C2/C3. Not clearly visible in STEREO A COR2 imagery, and possibly obscured by the bright streamer. The potential source is opening field lines best seen in GOES SUVI 284 at 2024-09-23T02:00Z, on the far side.",
#         "submissionTime": "2024-09-23T18:44Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/33551/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-09-23T08:47Z",
#                 "latitude": 36.0,
#                 "longitude": null,
#                 "halfAngle": 15.0,
#                 "speed": 512.0,
#                 "type": "C",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "Plane-of-sky",
#                 "note": "Plane of sky measurement using SOHO LASCO C2 imagery in SWPC_CAT.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": 5.6,
#                 "submissionTime": "2024-09-23T18:44Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/33552/-1",
#                 "enlilList": null
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2024-09-23T09:12:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-09-23T09:12Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             },
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "sourceLocation": "N50W20",
#         "activeRegionNum": null,
#         "note": "Faint CME seen to the NE in SOHO LASCO C2/C3 and STEREO A COR2. The potential source is a filament eruption seen lifting off starting around 2024-09-23T07:17Z in SDO AIA 304 centered around N50W20. Dimming is also visible in SDO AIA 193. The eruption is also visible from the point of view of STEREO A EUV 195. While the filament does not clearly deflect in EUV imagery, this is the most likely candidate source for this CME based on event timing and location.",
#         "submissionTime": "2024-09-23T18:56Z",
#         "versionId": 3,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/33546/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-09-23T16:40Z",
#                 "latitude": 41.0,
#                 "longitude": -20.0,
#                 "halfAngle": 14.0,
#                 "speed": 454.0,
#                 "type": "S",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Measurement based on best fit between SOHO LASCO C2/C3 and STEREO A COR2 imagery in SWPC_CAT.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": 10.0,
#                 "submissionTime": "2024-09-23T17:42Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/33547/-1",
#                 "enlilList": [
#                     {
#                         "modelCompletionTime": "2024-09-23T18:21Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": null,
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": null,
#                         "kp_135": null,
#                         "kp_180": null,
#                         "isEarthGB": false,
#                         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/33562/-1",
#                         "impactList": null,
#                         "cmeIDs": [
#                             "2024-09-23T09:12:00-CME-001"
#                         ]
#                     }
#                 ]
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2024-09-23T20:48:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-09-23T20:48Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             },
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "sourceLocation": "S33W23",
#         "activeRegionNum": null,
#         "note": "Slow, loop-shaped CME seen propagating to the southwest in SOHO C2/C3 starting around 2024-09-23T20:48Z and also seen in STEREO A which accelerates with time. May be associated with two areas of dimming seen best in GOES 284 which may represent footpoints for this eruption near S40W05 and S25W40 (centerpoint S33W23) located near the vicinity of AR3827.",
#         "submissionTime": "2024-09-24T12:18Z",
#         "versionId": 2,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/33557/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-09-24T10:13Z",
#                 "latitude": -38.0,
#                 "longitude": 23.0,
#                 "halfAngle": 30.0,
#                 "speed": 338.0,
#                 "type": "S",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Two spacecraft measurement of the leading edge of the CME, capturing the half-width more closely in STEREO A than SOHO, where it appears wider.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": 18.0,
#                 "submissionTime": "2024-09-24T12:04Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/33558/-1",
#                 "enlilList": [
#                     {
#                         "modelCompletionTime": "2024-09-24T12:01Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": "2024-09-28T00:00Z",
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": 3,
#                         "kp_135": 4,
#                         "kp_180": 5,
#                         "isEarthGB": true,
#                         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/33559/-1",
#                         "impactList": [
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "Mars",
#                                 "arrivalTime": "2024-09-30T22:00Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "STEREO A",
#                                 "arrivalTime": "2024-09-28T04:00Z"
#                             }
#                         ],
#                         "cmeIDs": [
#                             "2024-09-23T20:48:00-CME-001"
#                         ]
#                     }
#                 ]
#             }
#         ],
#         "linkedEvents": [
#             {
#                 "activityID": "2024-09-28T07:00:00-IPS-001"
#             }
#         ]
#     },
#     {
#         "activityID": "2024-09-24T04:12:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-09-24T04:12Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             },
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "sourceLocation": "S60W02",
#         "activeRegionNum": null,
#         "note": "CME seen to the south-southeast in SOHO/STEREO A imagery, overlapping with CME: 2024-09-23T20:48Z; possibly associated with a filament eruption at far southern latitudes seen best in SDO 171 around 2024-09-24T01:48Z.",
#         "submissionTime": "2024-09-24T12:57Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/33560/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-09-24T10:06Z",
#                 "latitude": -53.0,
#                 "longitude": -22.0,
#                 "halfAngle": 20.0,
#                 "speed": 577.0,
#                 "type": "C",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Leading edge measurement using triangulation between SOHO and STEREO Ahead; the CME could not be fit to the far-side.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": 11.0,
#                 "submissionTime": "2024-09-24T13:22Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/33561/-1",
#                 "enlilList": null
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2024-09-25T04:53:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-09-25T04:53Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             },
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "note": "Faint outflow type puff CME to the S/SW in STEREO A COR2 imagery and later frames in SOHO LASCO C3 imagery following a data gap. (Not visible in SOHO LASCO C2 imagery due to data gap). There is no clear source for this CME.",
#         "submissionTime": "2024-09-25T13:24Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/33565/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-09-25T13:48Z",
#                 "latitude": -47.0,
#                 "longitude": 38.0,
#                 "halfAngle": 11.0,
#                 "speed": 393.0,
#                 "type": "S",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Parameters based on best fit in SOHO LASCO C3 and STEREO A COR2 imagery.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": 13.5,
#                 "submissionTime": "2024-09-25T13:29Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/33566/-1",
#                 "enlilList": null
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2024-09-26T05:38:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-09-26T05:38Z",
#         "instruments": [
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "sourceLocation": "S35E70",
#         "activeRegionNum": null,
#         "note": "This CME is visible to the southeast in STEREO A COR2 imagery. It is not visible in SOHO LASCO C2 imagery due to a data gap lasing from 2024-09-26T04:00Z-07:36Z, and the event is obscured by the pylon in SOHO LASCO C3. The source is likely an eruption from S35E70 starting around 2024-09-26T04:00Z as seen in SDO AIA 131, 171, 193, 304 imagery. An opening of field lines is visible over the southeast limb at this time in SDO AIA 171 and 193 as well",
#         "submissionTime": "2024-09-26T17:14Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/33575/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-09-26T18:37Z",
#                 "latitude": -58.0,
#                 "longitude": -70.0,
#                 "halfAngle": 33.0,
#                 "speed": 261.0,
#                 "type": "S",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Longitude based on the source location. The measured parameters may vary slightly as there is a data gap in SOHO imagery at the time of this event.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": 8.4,
#                 "submissionTime": "2024-09-26T17:16Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/33576/-1",
#                 "enlilList": null
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2024-09-26T09:36:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-09-26T09:36Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             },
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "note": "This CME is visible to the southwest in SOHO LASCO C2/C3 and STEREO A COR2 imagery. The source is likely far-sided and may be related to filamentary material which is barely visible over/beyond the southwest limb in SDO AIA 304 imagery starting around 2024-08-26T07:40Z. An opening of field lines visible over the southwest limb in GOES SUVI 284 imagery starting around 2024-09-26T10:00Z as well.",
#         "submissionTime": "2024-09-26T17:21Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/33577/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-09-26T19:29Z",
#                 "latitude": -38.0,
#                 "longitude": 134.0,
#                 "halfAngle": 49.0,
#                 "speed": 415.0,
#                 "type": "S",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Measurement based on the best fit between SOHO LASCO C3 and STEREO A COR2 imagery. As the source is far-sided and the precise source location is unknown, the measured parameters may vary slightly.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": 14.2,
#                 "submissionTime": "2024-09-26T17:25Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/33578/-1",
#                 "enlilList": [
#                     {
#                         "modelCompletionTime": "2024-09-26T17:41Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": null,
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": null,
#                         "kp_135": null,
#                         "kp_180": null,
#                         "isEarthGB": false,
#                         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/33581/-1",
#                         "impactList": null,
#                         "cmeIDs": [
#                             "2024-09-26T09:36:00-CME-001"
#                         ]
#                     }
#                 ]
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2024-09-26T14:36:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-09-26T14:36Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             },
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "note": "This CME is visible to the northeast in SOHO LASCO C2/C3 imagery. It is faintly visible to the north in STEREO A COR2 imagery. The source is likely far-sided and may be related to faint field line movement visible over the northeast limb in SDO AIA 171 around 2024-09-26T13:00Z.",
#         "submissionTime": "2024-09-26T17:40Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/33579/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-09-27T01:44Z",
#                 "latitude": 65.0,
#                 "longitude": null,
#                 "halfAngle": 39.0,
#                 "speed": 319.0,
#                 "type": "S",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "Plane-of-sky",
#                 "note": "A plane-of-sky measurement was made using SOHO LASCO C2 imagery as the CME is too faintly observed in STEREO A COR2 to make a reliable measurement using this imagery.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": 5.0,
#                 "submissionTime": "2024-09-26T17:44Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/33580/-1",
#                 "enlilList": null
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2024-09-26T20:00:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-09-26T20:00Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             }
#         ],
#         "sourceLocation": "S12E75",
#         "activeRegionNum": 13839,
#         "note": "This CME is faintly visible to the east in SOHO LASCO C2, C3 and STEREO A COR2 imagery (more easily in difference imagery than white light imagery). The source appears to be a C5.0 flare and filament ejecta from newly numbered AR 3839 in the SE of the Earth-facing disk. The eruption is best seen in SDO/AIA 131 and 304 as well as GOES SUVI 304 imagery starting around 2024-09-26T19:45Z.",
#         "submissionTime": "2024-09-27T01:50Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/33583/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-09-27T07:16Z",
#                 "latitude": -8.0,
#                 "longitude": -75.0,
#                 "halfAngle": 30.0,
#                 "speed": 324.0,
#                 "type": "S",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Parameters based on best fit of leading edge in SOHO LASCO C2 and C3 imagery using potential source location. The feature becomes too faint/diffused in later frames to track. No good STEREO A frames to use in measurement.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": 6.2,
#                 "submissionTime": "2024-09-27T01:55Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/33584/-1",
#                 "enlilList": [
#                     {
#                         "modelCompletionTime": "2024-09-27T02:11Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": null,
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": null,
#                         "kp_135": null,
#                         "kp_180": null,
#                         "isEarthGB": false,
#                         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/33586/-1",
#                         "impactList": [
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "Solar Orbiter",
#                                 "arrivalTime": "2024-09-28T06:00Z"
#                             }
#                         ],
#                         "cmeIDs": [
#                             "2024-09-26T20:00:00-CME-001"
#                         ]
#                     }
#                 ]
#             }
#         ],
#         "linkedEvents": [
#             {
#                 "activityID": "2024-09-26T19:41:00-FLR-001"
#             }
#         ]
#     },
#     {
#         "activityID": "2024-09-27T09:24:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-09-27T09:24Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             },
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "note": "Disjoint CME seen to the east made up of a southeasterly, wider portion and a northeasterly, jet-like portion. Analysis focuses on the southeasterly portion. May be associated with a minor filament seen near 09:00Z in GOES 304/SDO 304 or activity (moving and opening field lines) associated with active regions that are turning on to the Earth-facing disk.",
#         "submissionTime": "2024-09-27T12:19Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/33587/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-09-27T16:07Z",
#                 "latitude": -12.0,
#                 "longitude": -88.0,
#                 "halfAngle": 25.0,
#                 "speed": 515.0,
#                 "type": "C",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Two spacecraft measurement using triangulation of the leading edge to determine a potential longitude; uncertainty in longitude approximately +/- 15 degrees. Was found to likely not be associated with on-disk activity.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": 8.0,
#                 "submissionTime": "2024-09-27T12:23Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/33588/-1",
#                 "enlilList": [
#                     {
#                         "modelCompletionTime": "2024-09-27T12:16Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": null,
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": null,
#                         "kp_135": null,
#                         "kp_180": null,
#                         "isEarthGB": false,
#                         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/33589/-1",
#                         "impactList": [
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "Solar Orbiter",
#                                 "arrivalTime": "2024-09-28T08:06Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "OSIRIS-APEX",
#                                 "arrivalTime": "2024-09-29T17:00Z"
#                             }
#                         ],
#                         "cmeIDs": [
#                             "2024-09-27T09:24:00-CME-001"
#                         ]
#                     }
#                 ]
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2024-09-28T06:36:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-09-28T06:36Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             },
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "note": "Faint hollow loop CME seen to the SE in SOHO LASCO C2/C3 and STEREO A COR2. The exact source is elusive. There has been continuous gentle field line movement on the SE limb over the course of several hours around this time, which may have possibly released some material. STEREO A is in campaign mode for the Parker Solar Probe perihelion pass, affecting COR2A image cadence and quality.",
#         "submissionTime": "2024-09-28T19:58Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/33593/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-09-28T17:18Z",
#                 "latitude": -56.0,
#                 "longitude": -38.0,
#                 "halfAngle": 27.0,
#                 "speed": 481.0,
#                 "type": "S",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Best fit measurement between C2/C3 and COR2A. Leading edge accelerates in C2. STEREO A is in campaign mode for the Parker Solar Probe perihelion pass, affecting COR2A image cadence and quality.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": 14.0,
#                 "submissionTime": "2024-09-28T20:00Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/33594/-1",
#                 "enlilList": null
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2024-09-28T11:00:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-09-28T11:00Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             },
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "sourceLocation": "S15W35",
#         "activeRegionNum": 13834,
#         "note": "Narrow CME visible to the SW in SOHO LASCO C2/C3 and STEREO A COR2. The potential source is an eruption seen in SDO AIA 193 starting at 2024-09-28T10:27Z, also visible in STEREO A EUV 195, around S15W35, from AR 3834. There is also field line movement seen beyond the west limb in STEREO A EUV 195 and SDO AIA 171/193 starting at 2024-09-28T10:48Z, which may be from a separate eruption on the far side.",
#         "submissionTime": "2024-09-28T23:15Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/33595/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-09-29T01:36Z",
#                 "latitude": -28.0,
#                 "longitude": 54.0,
#                 "halfAngle": 14.0,
#                 "speed": 250.0,
#                 "type": "S",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Measurement based on SOHO LASCO C2/C3 and limited available frames of STEREO A COR2 imagery due to ongoing STEREO A campaign.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": 7.3,
#                 "submissionTime": "2024-09-28T23:16Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/33596/-1",
#                 "enlilList": null
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2024-09-28T17:00:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-09-28T17:00Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             },
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "sourceLocation": "",
#         "activeRegionNum": null,
# ...
#                         ]
#                     }
#                 ]
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2024-10-18T11:36:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-10-18T11:36Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             },
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "note": "Faint CME with a fuzzy front, preceded and followed by outflows and following the slow/faint 2024-10-18T06:12Z CME. The start time of this event can be a bit earlier. The source is possibly a very minor faint eruption with ejecta/movement of field lines seen on/behind the NW limb in AIA 193/171 starting at 2024-10-18T11:30Z.",
#         "submissionTime": "2024-10-18T18:42Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34070/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-10-18T23:37Z",
#                 "latitude": 36.0,
#                 "longitude": 102.0,
#                 "halfAngle": 29.0,
#                 "speed": 305.0,
#                 "type": "S",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "A very approximate measurement based on the fit with two coronagraphs. The source is likely behind the limb and the fit gives a range of possible longitudes. Additionally, the front is very fuzzy.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": null,
#                 "submissionTime": "2024-10-18T18:44Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34071/-1",
#                 "enlilList": [
#                     {
#                         "modelCompletionTime": "2024-10-18T18:47Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": null,
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": null,
#                         "kp_135": null,
#                         "kp_180": null,
#                         "isEarthGB": false,
#                         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/34074/-1",
#                         "impactList": null,
#                         "cmeIDs": [
#                             "2024-10-18T11:36:00-CME-001"
#                         ]
#                     }
#                 ]
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2024-10-19T07:12:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-10-19T07:12Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             }
#         ],
#         "sourceLocation": "S03W82",
#         "activeRegionNum": 13854,
#         "note": "Faint diffuse CME to the W/SW in SOHO LASCO C2, C3 (barely visible), and possibly STEREO A COR2 imagery (unclear if feature seen to the west in STA is outflow or this CME). This CME is likely associated with the M6.5 flare from AR13854 (S03W82) peaking at 2024-10-19T06:56Z best seen in SDO/AIA 131. A filament to the north of the AR begins to erupt around 2024-10-19T06:24Z as seen in SDO/AIA 304 and appears to lift off with the flare and may be associated with this CME as well.",
#         "submissionTime": "2024-10-19T15:16Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34080/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-10-19T20:41Z",
#                 "latitude": -9.0,
#                 "longitude": 82.0,
#                 "halfAngle": 21.0,
#                 "speed": 275.0,
#                 "type": "S",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "These parameters are based on the source location of the M6.5 flare. The CME features are not visible in SOHO LASCO C3 and STEREO A COR2 difference imagery. Due to single spacecraft mode, there is a larger amount of uncertainty with this measurement.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": 6.0,
#                 "submissionTime": "2024-10-19T15:17Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34081/-1",
#                 "enlilList": null
#             }
#         ],
#         "linkedEvents": [
#             {
#                 "activityID": "2024-10-19T06:48:00-FLR-001"
#             }
#         ]
#     },
#     {
#         "activityID": "2024-10-19T09:24:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-10-19T09:24Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             },
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "sourceLocation": "S10E65",
#         "activeRegionNum": 13863,
#         "note": "This CME is visible to the E/NE in SOHO LASCO C2, C3, and STEREO A COR2 imagery. The source appears to be an eruption from AR 3863 starting around 2024-10-19T09:00Z in SDO/AIA 304/171/211/94. Moving/opening field lines are visible in the SE of SDO/AIA 171, however it is not clear if these moving/opening field lines are associated with this eruption or another eruption that may be associated with the CME first seen in SOHO LASCO C2 at 2024-10-19T09:48Z to the SE.",
#         "submissionTime": "2024-10-19T18:25Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34082/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-10-19T13:03Z",
#                 "latitude": 19.0,
#                 "longitude": -73.0,
#                 "halfAngle": 34.0,
#                 "speed": 1015.0,
#                 "type": "O",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Parameters based on best fit of features in SOHO LASCO C3 and STEREO A COR2 imagery.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": 14.4,
#                 "submissionTime": "2024-10-19T18:26Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34083/-1",
#                 "enlilList": [
#                     {
#                         "modelCompletionTime": "2024-10-19T18:47Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": null,
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": null,
#                         "kp_135": null,
#                         "kp_180": null,
#                         "isEarthGB": false,
#                         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/34084/-1",
#                         "impactList": [
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "Parker Solar Probe",
#                                 "arrivalTime": "2024-10-20T09:29Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "Lucy",
#                                 "arrivalTime": "2024-10-21T16:00Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "OSIRIS-APEX",
#                                 "arrivalTime": "2024-10-21T04:00Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "Solar Orbiter",
#                                 "arrivalTime": "2024-10-20T14:00Z"
#                             }
#                         ],
#                         "cmeIDs": [
#                             "2024-10-19T09:24:00-CME-001"
#                         ]
#                     }
#                 ]
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2024-10-19T09:48:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-10-19T09:48Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             },
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "note": "Narrow CME to the south. A potential source could be the opening of field lines to the S/SE in SDO/AIA 171 around 2024-10-19T09Z.",
#         "submissionTime": "2024-10-19T20:23Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34087/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-10-19T14:31Z",
#                 "latitude": -64.0,
#                 "longitude": -148.0,
#                 "halfAngle": 14.0,
#                 "speed": 708.0,
#                 "type": "C",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Analysis based on the best fit with two coronagraphs. Only backsided longitude and high southern latitude produce a fit.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": null,
#                 "submissionTime": "2024-10-19T20:25Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34088/-1",
#                 "enlilList": null
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2024-10-19T19:00:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-10-19T19:00Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             },
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "note": "Narrow faint CME with a dimpled front. The likely source is a minor movement of field line behind the northwest limb at latitude ~20 seen starting around 2024-10-19T17:40Z in AIA 193/171.",
#         "submissionTime": "2024-10-19T23:43Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34089/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-10-20T04:27Z",
#                 "latitude": 25.0,
#                 "longitude": 124.0,
#                 "halfAngle": 15.0,
#                 "speed": 364.0,
#                 "type": "S",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Approximate analysis based on the fit in two coronagraphs. The source is behind the limb and the front is faint and diffuse. Not simulated because there are no missions in the CME's path.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": null,
#                 "submissionTime": "2024-10-19T23:46Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34090/-1",
#                 "enlilList": null
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2024-10-19T22:36:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-10-19T22:36Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             },
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "note": "Minor faint CME to the southeast, becoming wider with time, consisting of a faint shock on its sides. The source for this eruption appears to be movement/opening of field lines just behind the SE limb (lat ~-20) seen around 2024-10-19T22:30Z.",
#         "submissionTime": "2024-10-20T14:34Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34091/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-10-20T08:19Z",
#                 "latitude": -36.0,
#                 "longitude": -104.0,
#                 "halfAngle": 31.0,
#                 "speed": 466.0,
#                 "type": "S",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Two spacecraft leading edge measurement to approximate longitude; longitude parameter has uncertainty of about +/- 15 degrees.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": 11.0,
#                 "submissionTime": "2024-10-20T14:37Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34092/-1",
#                 "enlilList": [
#                     {
#                         "modelCompletionTime": "2024-10-20T14:27Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": null,
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": null,
#                         "kp_135": null,
#                         "kp_180": null,
#                         "isEarthGB": false,
#                         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/34093/-1",
#                         "impactList": [
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "OSIRIS-APEX",
#                                 "arrivalTime": "2024-10-22T15:00Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "Lucy",
#                                 "arrivalTime": "2024-10-21T15:00Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "Parker Solar Probe",
#                                 "arrivalTime": "2024-10-21T22:00Z"
#                             }
#                         ],
#                         "cmeIDs": [
#                             "2024-10-19T22:36:00-CME-001"
#                         ]
#                     }
#                 ]
#             }
#         ],
#         "linkedEvents": null
#     }
# ]

# %%
# Convert cme_json to a Pandas DataFrame 
cme_df = pd.json_normalize(cme_json)
cme_df

# Keep only the columns: activityID, startTime, linkedEvents
cme_sorted = cme_df[['activityID', 'startTime', 'linkedEvents']]
cme_sorted
# Out:
#                       activityID          startTime  \
# 0    2024-09-21T11:12:00-CME-001  2024-09-21T11:12Z
# 1    2024-09-21T16:12:00-CME-001  2024-09-21T16:12Z
# 2    2024-09-21T20:00:00-CME-001  2024-09-21T20:00Z
# 3    2024-09-22T07:12:00-CME-001  2024-09-22T07:12Z
# 4    2024-09-22T14:48:00-CME-001  2024-09-22T14:48Z
# ..                           ...                ...
# 112  2024-10-19T07:12:00-CME-001  2024-10-19T07:12Z
# 113  2024-10-19T09:24:00-CME-001  2024-10-19T09:24Z
# 114  2024-10-19T09:48:00-CME-001  2024-10-19T09:48Z
# 115  2024-10-19T19:00:00-CME-001  2024-10-19T19:00Z
# 116  2024-10-19T22:36:00-CME-001  2024-10-19T22:36Z
#
#                                         linkedEvents
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
# ..                                               ...
# 112  [{'activityID': '2024-10-19T06:48:00-FLR-001'}]
# 113                                             None
# 114                                             None
# 115                                             None
# 116                                             None
#
# [117 rows x 3 columns]

# %%
# Notice that the linkedEvents column allows us to identify the corresponding GST
# Remove rows with missing 'linkedEvents' since we won't be able to assign these to GSTs
cme_cleaned = cme_sorted[cme_sorted['linkedEvents'].notna()]
#cme_cleaned = cme_sorted.dropna
cme_cleaned.head(30)
# Out:
#                       activityID          startTime  \
# 6    2024-09-22T21:36:00-CME-001  2024-09-22T21:36Z
# 9    2024-09-23T20:48:00-CME-001  2024-09-23T20:48Z
# 15   2024-09-26T20:00:00-CME-001  2024-09-26T20:00Z
# 20   2024-09-29T06:00:00-CME-001  2024-09-29T06:00Z
# 30   2024-10-01T01:09:00-CME-001  2024-10-01T01:09Z
# 34   2024-10-01T23:09:00-CME-001  2024-10-01T23:09Z
# 35   2024-10-02T06:36:00-CME-001  2024-10-02T06:36Z
# 36   2024-10-02T14:24:00-CME-001  2024-10-02T14:24Z
# 40   2024-10-03T12:48:00-CME-001  2024-10-03T12:48Z
# 43   2024-10-03T20:36:00-CME-001  2024-10-03T20:36Z
# 46   2024-10-04T04:13:00-CME-001  2024-10-04T04:13Z
# 47   2024-10-04T05:12:00-CME-001  2024-10-04T05:12Z
# 66   2024-10-07T20:12:00-CME-001  2024-10-07T20:12Z
# 72   2024-10-09T02:12:00-CME-001  2024-10-09T02:12Z
# 74   2024-10-09T16:12:00-CME-001  2024-10-09T16:12Z
# 81   2024-10-11T17:38:00-CME-001  2024-10-11T17:38Z
# 91   2024-10-14T00:48:00-CME-001  2024-10-14T00:48Z
# 95   2024-10-14T14:36:00-CME-001  2024-10-14T14:36Z
# 101  2024-10-15T22:06:00-CME-001  2024-10-15T22:06Z
# 112  2024-10-19T07:12:00-CME-001  2024-10-19T07:12Z
#
#                                           linkedEvents
# 6      [{'activityID': '2024-09-22T21:12:00-FLR-001'}]
# 9      [{'activityID': '2024-09-28T07:00:00-IPS-001'}]
# 15     [{'activityID': '2024-09-26T19:41:00-FLR-001'}]
# 20     [{'activityID': '2024-09-29T05:26:00-FLR-001'}]
# 30     [{'activityID': '2024-09-30T23:37:00-FLR-001'}]
# 34     [{'activityID': '2024-10-01T21:58:00-FLR-001'}]
# 35     [{'activityID': '2024-10-02T05:30:00-FLR-001'}]
# 36     [{'activityID': '2024-10-02T13:22:00-FLR-001'}]
# 40   [{'activityID': '2024-10-03T12:08:00-FLR-001'}...
# 43   [{'activityID': '2024-10-03T20:09:00-FLR-001'}...
# 46     [{'activityID': '2024-10-07T22:12:00-IPS-001'}]
# 47     [{'activityID': '2024-10-04T04:36:00-FLR-001'}]
# 66   [{'activityID': '2024-10-07T19:02:00-FLR-001'}...
# 72   [{'activityID': '2024-10-09T01:25:00-FLR-001'}...
# 74     [{'activityID': '2024-10-09T15:44:00-FLR-001'}]
# 81     [{'activityID': '2024-10-11T16:07:00-FLR-001'}]
# 91     [{'activityID': '2024-10-14T00:04:00-FLR-001'}]
# 95     [{'activityID': '2024-10-14T13:22:00-FLR-001'}]
# 101    [{'activityID': '2024-10-15T18:00:00-FLR-001'}]
# 112    [{'activityID': '2024-10-19T06:48:00-FLR-001'}]

# %%
# Notice that the linkedEvents sometimes contains multiple events per row
# Write a nested for loop that iterates first over each row in the cme DataFrame (using the index)
for i in range(len(cme_cleaned)):
    #print(cme_cleaned.iloc[i])
    activity_id = cme_cleaned.iloc[i]['activityID']
    start_time = cme_cleaned.iloc[i]['startTime']
    linked_events = cme_cleaned.iloc[i]['linkedEvents']
# and then iterates over the values in 'linkedEvents' 
linkedEvents_value = cme_cleaned.iloc[3]['activityID']
# and adds the elements individually to a list of dictionaries where each row is one element 

# Initialize an empty list to store the expanded rows
expanded_rows = []

# Iterate over each index in the DataFrame
if isinstance(linked_events, list):
        for event in linked_events:
            expanded_rows.append({
                'activityID': activity_id,
                'startTime': start_time,
                'linkedEvent': event
            })
    # Iterate over each dictionary in the list
    
        # Append a new dictionary to the expanded_rows list for each dictionary item and corresponding 'activityID' and 'startTime' value
        #activity_id.append(cme_response: "")
        #start_time.append(cme_response: "")

# Create a new DataFrame from the expanded rows
expanded_df = pd.DataFrame(expanded_rows)
expanded_df.head(10)
# Out:
#                     activityID          startTime  \
# 0  2024-10-19T07:12:00-CME-001  2024-10-19T07:12Z
#
#                                      linkedEvent
# 0  {'activityID': '2024-10-19T06:48:00-FLR-001'}

# %%
# Create a function called extract_activityID_from_dict that takes a dict as input such as in linkedEvents
# and verify below that it works as expected using one row from linkedEvents as an example
# Be sure to use a try and except block to handle errors

        # Log the error or print it for debugging

# %%
# Apply this function to each row in the 'linkedEvents' column (you can use apply() and a lambda function)
# and create a new column called 'GST_ActivityID' using loc indexer:

# %%
# Remove rows with missing GST_ActivityID, since we can't assign them to GSTs:

# %%
# print out the datatype of each column in this DataFrame:

# %%
# Convert the 'GST_ActivityID' column to string format 

# Convert startTime to datetime format  

# Rename startTime to startTime_CME and activityID to cmeID

# Drop linkedEvents

# Verify that all steps were executed correctly

# %%
# We are only interested in CMEs related to GSTs so keep only rows where the GST_ActivityID column contains 'GST'
# use the method 'contains()' from the str library.

# %% [markdown]
# ### GST Data

# %%
# Set the base URL to NASA's DONKI API:
base_url = "https://api.nasa.gov/DONKI/"

# Set the specifier for Geomagnetic Storms (GST):
GST = "GST"

# Search for GSTs between a begin and end date
startDate = "2013-05-01"
endDate   = "2024-05-01"

# Build URL for GST

# %%
# Make a "GET" request for the GST URL and store it in a variable named gst_response

# %%
# Convert the response variable to json and store it as a variable named gst_json

# Preview the first result in JSON format
# Use json.dumps with argument indent=4 to format data

# %%
# Convert gst_json to a Pandas DataFrame  

# Keep only the columns: activityID, startTime, linkedEvents

# %%
# Notice that the linkedEvents column allows us to identify the corresponding CME
# Remove rows with missing 'linkedEvents' since we won't be able to assign these to CME

# %%
# Notice that the linkedEvents sometimes contains multiple events per row
# Use the explode method to ensure that each row is one element. Ensure to reset the index and drop missing values.

# %%
# Apply the extract_activityID_from_dict function to each row in the 'linkedEvents' column (you can use apply() and a lambda function)
# and create a new column called 'CME_ActivityID' using loc indexer:

# Remove rows with missing CME_ActivityID, since we can't assign them to CMEs:

# %%
# Convert the 'CME_ActivityID' column to string format 

# Convert the 'gstID' column to string format 

# Convert startTime to datetime format  

# Rename startTime to startTime_GST 

# Drop linkedEvents

# Verify that all steps were executed correctly

# %%
# We are only interested in GSTs related to CMEs so keep only rows where the CME_ActivityID column contains 'CME'
# use the method 'contains()' from the str library.

# %% [markdown]
# ### Merge both datatsets

# %%
# Now merge both datasets using 'gstID' and 'CME_ActivityID' for gst and 'GST_ActivityID' and 'cmeID' for cme. Use the 'left_on' and 'right_on' specifiers.

# %%
# Verify that the new DataFrame has the same number of rows as cme and gst

# %% [markdown]
# ### Computing the time it takes for a CME to cause a GST

# %%
# Compute the time diff between startTime_GST and startTime_CME by creating a new column called `timeDiff`.

# %%
# Use describe() to compute the mean and median time 
# that it takes for a CME to cause a GST.

# %% [markdown]
# ### Exporting data in csv format

# %%
# Export data to CSV without the index
